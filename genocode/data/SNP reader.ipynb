# %%
import pandas as pd
import numpy as np

# %%
ls
# Out:
# 23andMe_data.csv
# 23andMe_data.txt
# Genetic Statistical Data.xlsx - Initial data.csv
# Untitled.ipynb

# %%
df = pd.read_csv('Genetic Statistical Data.xlsx - Initial data.csv')

# %%
df
# Out:
#    phenotype        rsid    gene genotype effect Explained variance (%)  \
# 0        BMI   rs9939609     FTO       TT      0                   0.34
# 1        BMI   rs9939609     FTO       AT   0.36                   0.34
# 2        BMI   rs9939609     FTO       AA   0.72                   0.34
# 3        BMI   rs6548238  TMEM18       TT      0                   0.13
# 4        BMI   rs6548238  TMEM18       CT    0.2                   0.13
# 5        BMI   rs6548238  TMEM18       CC    0.4                   0.13
# 6        BMI  rs17782313    MC4R       TT      0                    0.1
# 7        BMI  rs17782313    MC4R       CT   0.28                    0.1
# 8        BMI  rs17782313    MC4R       CC   0.56                    0.1
# 9        BMI  rs10938397  GNPDA2       AA      0                   0.13
# 10       BMI  rs10938397  GNPDA2       AG   0.33                   0.13
# 11       BMI  rs10938397  GNPDA2       GG   0.66                   0.13
# ...

# %%
lowerci = np.array(df.loc[df['rsid']=='rs9939609']['lowerci'])
upperci = np.array(df.loc[df['rsid']=='rs9939609']['upperci'])

# %%
lowerci,upperci
# Out:
# (array([25.1, 25.6, 25.8]), array([25.6, 26. , 26.4]))
